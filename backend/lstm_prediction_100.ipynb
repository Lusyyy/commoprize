# %%
# Impor pustaka yang dibutuhkan
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping
import glob

# %%
# Setel seed acak untuk reproduktibilitas
np.random.seed(42)
import tensorflow as tf
tf.random.set_seed(42)

# %%
# Tentukan jalur ke data dan ambil semua file CSV
data_path = "C:/D/projects/BPP PROJECT/bpp-prediction/backend/datasets/"
csv_files = glob.glob(data_path + "*.csv")

# %%
# Fungsi untuk memuat dan membersihkan data (menangani nilai yang hilang)
def load_and_clean_data(file_path):
    df = pd.read_csv(file_path, delimiter=';')
    df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/%m/%Y')
    df.set_index('Tanggal', inplace=True)
    
    # Menangani data yang hilang
    df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
    
    return df

# %%
# Memuat semua dataset
datasets = {file.split("\\")[-1]: load_and_clean_data(file) for file in csv_files}
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang
# C:\Users\user\AppData\Local\Temp\ipykernel_13616\2808223563.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Menggunakan pengisian maju untuk menangani data yang hilang

# %%
# Menampilkan informasi dataset
for name, df in datasets.items():
    print(f"\nDataset: {name}")
    display(df.head())
# Kamus untuk menyimpan scaler untuk setiap dataset
scalers = {}
# Out:
# Dataset: bawang_merah.csv
#             Harga
# Tanggal
# 2021-04-01  27970
# 2021-04-02  27730
# 2021-04-03  27770
# 2021-04-04  27730
# 2021-04-05  27530
# Dataset: bawang_putih.csv
#             Harga
# Tanggal
# 2021-04-01  24220
# 2021-04-02  24090
# 2021-04-03  24080
# 2021-04-04  24280
# 2021-04-05  24120
# Dataset: beras_medium.csv
#             Harga
# Tanggal
# 2021-04-01  10180
# 2021-04-02  10110
# 2021-04-03  10180
# 2021-04-04  10140
# 2021-04-05  10090
# Dataset: beras_premium.csv
#             Harga
# Tanggal
# 2021-04-01  11380
# 2021-04-02  11350
# 2021-04-03  11420
# 2021-04-04  11380
# 2021-04-05  11330
# Dataset: cabai_merah_keriting.csv
#             Harga
# Tanggal
# 2021-04-01  46780
# 2021-04-02  47270
# 2021-04-03  48050
# 2021-04-04  47180
# 2021-04-05  47930
# Dataset: cabai_rawit_merah.csv
#             Harga
# Tanggal
# 2021-04-01  66080
# 2021-04-02  63860
# 2021-04-03  63800
# 2021-04-04  63760
# 2021-04-05  66590
# Dataset: daging_ayam_ras.csv
#             Harga
# Tanggal
# 2021-04-01  33980
# 2021-04-02  34000
# 2021-04-03  34210
# 2021-04-04  34310
# 2021-04-05  34960
# Dataset: daging_sapi.csv
#              Harga
# Tanggal
# 2021-04-01  109630
# 2021-04-02  109870
# 2021-04-03  109860
# 2021-04-04  110070
# 2021-04-05  109670
# Dataset: gula_pasir.csv
#             Harga
# Tanggal
# 2021-04-01  12200
# 2021-04-02  12180
# 2021-04-03  12140
# 2021-04-04  12150
# 2021-04-05  12160
# Dataset: kedelai.csv
#             Harga
# Tanggal
# 2021-04-01  10260
# 2021-04-02  10280
# 2021-04-03  10280
# 2021-04-04  10190
# 2021-04-05  10260
# Dataset: telur_ayam_ras.csv
#             Harga
# Tanggal
# 2021-04-01  20910
# 2021-04-02  21200
# 2021-04-03  21000
# 2021-04-04  21180
# 2021-04-05  21400

# %%
# Fungsi untuk menormalkan data
def normalize_data(df, dataset_name):
    """Menormalkan data dan menyimpan scaler untuk digunakan nanti"""
    scalers[dataset_name] = MinMaxScaler(feature_range=(0, 1))
    df_scaled = scalers[dataset_name].fit_transform(df[['Harga']].values)
    return df_scaled

# %%
# Menormalkan semua dataset
scaled_datasets = {}
for file, df in datasets.items():
    print(f"\nMenormalkan dataset: {file}")
    scaled_datasets[file] = normalize_data(df, file)
    
    # Menampilkan sampel nilai asli dan nilai terormalisasi
    print("Nilai asli:", df['Harga'].head().values)
    print("Nilai terormalisasi:", scaled_datasets[file][:5].flatten())
# Out:
# Menormalkan dataset: bawang_merah.csv
# Nilai asli: [27970 27730 27770 27730 27530]
# Nilai terormalisasi: [0.20358579 0.19855898 0.19939678 0.19855898 0.19436997]
#
# Menormalkan dataset: bawang_putih.csv
# Nilai asli: [24220 24090 24080 24280 24120]
# Nilai terormalisasi: [0.30012163 0.29353335 0.29302656 0.30316238 0.29505372]
#
# Menormalkan dataset: beras_medium.csv
# Nilai asli: [10180 10110 10180 10140 10090]
# Nilai terormalisasi: [0.23134891 0.21376539 0.23134891 0.22130118 0.20874152]
#
# Menormalkan dataset: beras_premium.csv
# Nilai asli: [11380 11350 11420 11380 11330]
# Nilai terormalisasi: [0.18579235 0.18032787 0.19307832 0.18579235 0.17668488]
#
# Menormalkan dataset: cabai_merah_keriting.csv
# Nilai asli: [46780 47270 48050 47180 47930]
# Nilai terormalisasi: [0.45205289 0.45887265 0.4697286  0.45762004 0.46805846]
#
# Menormalkan dataset: cabai_rawit_merah.csv
# Nilai asli: [66080 63860 63800 63760 66590]
# Nilai terormalisasi: [0.62580259 0.59865227 0.59791848 0.59742928 0.63203982]
#
# Menormalkan dataset: daging_ayam_ras.csv
# Nilai asli: [33980 34000 34210 34310 34960]
# Nilai terormalisasi: [0.49415003 0.4955265  0.50997935 0.51686167 0.5615967 ]
#
# Menormalkan dataset: daging_sapi.csv
# Nilai asli: [109630 109870 109860 110070 109670]
# Nilai terormalisasi: [0.03830622 0.05215184 0.05157494 0.06368986 0.04061382]
#
# Menormalkan dataset: gula_pasir.csv
# Nilai asli: [12200 12180 12140 12150 12160]
# Nilai terormalisasi: [0.06271186 0.05932203 0.05254237 0.05423729 0.0559322 ]
#
# Menormalkan dataset: kedelai.csv
# Nilai asli: [10260 10280 10280 10190 10260]
# Nilai terormalisasi: [0.10271318 0.10658915 0.10658915 0.08914729 0.10271318]
#
# Menormalkan dataset: telur_ayam_ras.csv
# Nilai asli: [20910 21200 21000 21180 21400]
# Nilai terormalisasi: [0.23942598 0.26132931 0.24622356 0.25981873 0.27643505]

# %%
import joblib

# Simpan semua scaler ke dalam file
scaler_path = "C:/D/projects/BPP PROJECT/bpp-prediction/backend/scalers_100/"
os.makedirs(scaler_path, exist_ok=True)

for dataset_name, scaler in scalers.items():
    joblib.dump(scaler, f"{scaler_path}{dataset_name}_scaler.pkl")

print("Semua scaler telah disimpan.")
# Out:
# Semua scaler telah disimpan.

# %%
# Fungsi untuk membuat urutan data untuk LSTM
def create_dataset(data, time_step=60):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
# Membuat urutan untuk setiap dataset
datasets_X_y = {}
for file, scaled_data in scaled_datasets.items():
    print(f"\nMembuat dataset untuk {file}")
    X, y = create_dataset(scaled_data)
    datasets_X_y[file] = (X, y)
    print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Membuat dataset untuk bawang_merah.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk bawang_putih.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk beras_medium.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk beras_premium.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk cabai_merah_keriting.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk cabai_rawit_merah.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk daging_ayam_ras.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk daging_sapi.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk gula_pasir.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk kedelai.csv
# X shape: (1279, 60), y shape: (1279,)
#
# Membuat dataset untuk telur_ayam_ras.csv
# X shape: (1279, 60), y shape: (1279,)

# %%
# Fungsi untuk membagi data
def split_data(X, y, train_size=0.8):
    train_len = int(len(X) * train_size)
    X_train, X_test = X[:train_len], X[train_len:]
    y_train, y_test = y[:train_len], y[train_len:]
    return X_train, X_test, y_train, y_test

# %%
# Membagi data untuk setiap dataset
split_datasets = {}
for file, (X, y) in datasets_X_y.items():
    print(f"\nMembagi data untuk {file}")
    X_train, X_test, y_train, y_test = split_data(X, y)
    split_datasets[file] = (X_train, X_test, y_train, y_test)
    print(f"Bentuk set pelatihan: {X_train.shape}")
    print(f"Bentuk set pengujian: {X_test.shape}")
# Out:
# Membagi data untuk bawang_merah.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk bawang_putih.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk beras_medium.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk beras_premium.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk cabai_merah_keriting.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk cabai_rawit_merah.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk daging_ayam_ras.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk daging_sapi.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk gula_pasir.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk kedelai.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)
#
# Membagi data untuk telur_ayam_ras.csv
# Bentuk set pelatihan: (1023, 60)
# Bentuk set pengujian: (256, 60)

# %%
# Fungsi untuk membangun model LSTM
def build_model(input_shape):
    model = Sequential([
        LSTM(units=50, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(units=50, return_sequences=False),
        Dropout(0.2),
        Dense(units=1)
    ])
    model.compile(optimizer=Adam(), loss='mean_squared_error')
    return model

# %%
# Melatih model untuk setiap dataset
model_results = {}
for file, (X_train, X_test, y_train, y_test) in split_datasets.items():
    print(f"\nMelatih model untuk {file}")
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    
    model = build_model((X_train.shape[1], 1))

    # Penghentian dini untuk mencegah overfitting
    early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stopping],
        verbose=1
    )
    
    # Menyimpan model
    model.save(f"C:/D/projects/BPP PROJECT/bpp-prediction/backend/models_100/{file}_model.h5")
    model_results[file] = model
    
    #  # Menampilkan Hidden State dan Cell State pada timestep terakhir
    # print("\nEvaluasi pada data uji (X_test):")
    # output, state_h, state_c = model.predict(X_test)
    # print("Hidden State terakhir (state_h):", state_h)
    # print("Cell State terakhir (state_c):", state_c)
    
    # Plot riwayat pelatihan
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Loss Pelatihan')
    plt.plot(history.history['val_loss'], label='Loss Validasi')
    plt.title(f'Loss Model untuk {file}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Melatih model untuk bawang_merah.csv
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0145 - val_loss: 0.0011
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0040 - val_loss: 7.9086e-04
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0026 - val_loss: 5.7462e-04
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0021 - val_loss: 8.4239e-04
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0023 - val_loss: 4.1719e-04
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0019 - val_loss: 3.9564e-04
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0014 - val_loss: 2.7542e-04
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0014 - val_loss: 4.1614e-04
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0015 - val_loss: 2.7150e-04
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0014 - val_loss: 3.9029e-04
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0014 - val_loss: 2.7338e-04
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0012 - val_loss: 1.9811e-04
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0013 - val_loss: 3.7219e-04
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0012 - val_loss: 1.9124e-04
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 9.8797e-04 - val_loss: 1.7133e-04
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0010 - val_loss: 1.9260e-04
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.0648e-04 - val_loss: 1.9540e-04
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.9537e-04 - val_loss: 1.8680e-04
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.0355e-04 - val_loss: 4.0503e-04
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.1528e-04 - val_loss: 1.5917e-04
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.7952e-04 - val_loss: 1.5241e-04
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.6892e-04 - val_loss: 1.4872e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.4585e-04 - val_loss: 1.4728e-04
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.5971e-04 - val_loss: 2.0963e-04
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.2474e-04 - val_loss: 1.7185e-04
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.4611e-04 - val_loss: 1.7168e-04
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.8612e-04 - val_loss: 1.5218e-04
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.3742e-04 - val_loss: 1.5988e-04
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.3894e-04 - val_loss: 1.3974e-04
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.2233e-04 - val_loss: 1.6271e-04
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.2137e-04 - val_loss: 1.2849e-04
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 7.4589e-04 - val_loss: 1.2003e-04
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.6454e-04 - val_loss: 1.3109e-04
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.6441e-04 - val_loss: 2.0420e-04
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.7851e-04 - val_loss: 1.3789e-04
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.1698e-04 - val_loss: 1.1862e-04
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.0608e-04 - val_loss: 1.6126e-04
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.5746e-04 - val_loss: 1.1682e-04
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.9907e-04 - val_loss: 2.0464e-04
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.4600e-04 - val_loss: 1.8875e-04
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.9160e-04 - val_loss: 1.7325e-04
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.3995e-04 - val_loss: 2.1602e-04
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.1266e-04 - val_loss: 1.0847e-04
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.7448e-04 - val_loss: 1.3117e-04
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.0642e-04 - val_loss: 1.3492e-04
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.1216e-04 - val_loss: 2.1117e-04
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.6742e-04 - val_loss: 1.2949e-04
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.8234e-04 - val_loss: 1.0421e-04
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.4138e-04 - val_loss: 1.1737e-04
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.5041e-04 - val_loss: 1.1735e-04
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.8359e-04 - val_loss: 1.0837e-04
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.6049e-04 - val_loss: 1.0904e-04
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.8880e-04 - val_loss: 9.8292e-05
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.2920e-04 - val_loss: 3.5275e-04
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.7729e-04 - val_loss: 1.0425e-04
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.5121e-04 - val_loss: 1.5440e-04
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.3366e-04 - val_loss: 1.3099e-04
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.2166e-04 - val_loss: 9.2911e-05
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.8163e-04 - val_loss: 9.8082e-05
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.3306e-04 - val_loss: 1.7217e-04
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.4759e-04 - val_loss: 1.5820e-04
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.1029e-04 - val_loss: 1.0956e-04
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.6333e-04 - val_loss: 1.2844e-04
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.6469e-04 - val_loss: 9.5435e-05
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.0823e-04 - val_loss: 9.4021e-05
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3789e-04 - val_loss: 1.0588e-04
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.6687e-04 - val_loss: 1.6289e-04
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.7773e-04 - val_loss: 1.0514e-04
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.1617e-04 - val_loss: 9.8087e-05
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.3727e-04 - val_loss: 1.3717e-04
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.9153e-04 - val_loss: 1.7706e-04
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.5148e-04 - val_loss: 1.0494e-04
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.0210e-04 - val_loss: 1.6669e-04
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.2734e-04 - val_loss: 9.3965e-05
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.6560e-04 - val_loss: 9.8511e-05
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.1289e-04 - val_loss: 1.7978e-04
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.5112e-04 - val_loss: 1.3947e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.5491e-04 - val_loss: 1.0195e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Melatih model untuk bawang_putih.csv
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0942 - val_loss: 0.0040
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0028 - val_loss: 7.0204e-04
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0034 - val_loss: 6.2279e-04
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0025 - val_loss: 8.9987e-04
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0024 - val_loss: 6.9636e-04
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0021 - val_loss: 5.4524e-04
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0023 - val_loss: 5.2738e-04
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0023 - val_loss: 7.2348e-04
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0023 - val_loss: 6.2426e-04
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0021 - val_loss: 9.2061e-04
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0024 - val_loss: 5.7064e-04
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0021 - val_loss: 7.0066e-04
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0019 - val_loss: 6.8073e-04
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0021 - val_loss: 4.1616e-04
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0020 - val_loss: 3.3563e-04
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0020 - val_loss: 3.3913e-04
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0017 - val_loss: 6.9966e-04
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0019 - val_loss: 6.1282e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0017 - val_loss: 9.0361e-04
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0014 - val_loss: 3.1138e-04
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0016 - val_loss: 7.7449e-04
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0014 - val_loss: 2.9448e-04
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0017 - val_loss: 3.8913e-04
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0016 - val_loss: 3.2320e-04
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0018 - val_loss: 9.0111e-04
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0018 - val_loss: 2.6681e-04
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0015 - val_loss: 2.6498e-04
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0014 - val_loss: 3.0064e-04
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0015 - val_loss: 3.1088e-04
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.
-04
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.4497e-04 - val_loss: 0.0013
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 9.2905e-04 - val_loss: 0.0010
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.4406e-04 - val_loss: 0.0031
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0010 - val_loss: 3.3925e-04
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.8850e-04 - val_loss: 5.2364e-04
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.2474e-04 - val_loss: 8.6298e-04
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.6168e-04 - val_loss: 3.9596e-04
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.1169e-04 - val_loss: 3.7783e-04
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.8499e-04 - val_loss: 6.1079e-04
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.7689e-04 - val_loss: 0.0012
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.3950e-04 - val_loss: 0.0011
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.7728e-04 - val_loss: 0.0011
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.1582e-04 - val_loss: 3.3278e-04
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.2244e-04 - val_loss: 0.0016
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.4728e-04 - val_loss: 0.0019
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.2007e-04 - val_loss: 5.5842e-04
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.2726e-04 - val_loss: 8.0501e-04
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.1392e-04 - val_loss: 5.6516e-04
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.5190e-04 - val_loss: 5.6430e-04
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.6328e-04 - val_loss: 3.2747e-04
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.3796e-04 - val_loss: 3.2707e-04
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.3203e-04 - val_loss: 7.9976e-04
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.5269e-04 - val_loss: 0.0010
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.2180e-04 - val_loss: 3.4672e-04
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.4178e-04 - val_loss: 3.0958e-04
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.7160e-04 - val_loss: 5.7431e-04
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.9396e-04 - val_loss: 0.0016
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.5374e-04 - val_loss: 4.7895e-04
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.2229e-04 - val_loss: 8.0964e-04
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.6834e-04 - val_loss: 6.0023e-04
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.8172e-04 - val_loss: 9.6445e-04
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.8795e-04 - val_loss: 0.0010
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.7501e-04 - val_loss: 6.7398e-04
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.4449e-04 - val_loss: 3.1522e-04
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.4630e-04 - val_loss: 5.0911e-04
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.2721e-04 - val_loss: 3.8507e-04
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.4866e-04 - val_loss: 8.4660e-04
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.6850e-04 - val_loss: 3.8430e-04
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.7877e-04 - val_loss: 3.6187e-04
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.3244e-04 - val_loss: 3.2611e-04
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.2704e-04 - val_loss: 3.1144e-04
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.6130e-04 - val_loss: 4.1331e-04
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.1098e-04 - val_loss: 0.0015
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.7929e-04 - val_loss: 7.7164e-04
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.6028e-04 - val_loss: 0.0016
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Melatih model untuk beras_premium.csv
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0370 - val_loss: 0.0030
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.4863e-04 - val_loss: 0.0020
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0010 - val_loss: 9.8583e-04
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.3428e-04 - val_loss: 0.0010
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.3245e-04 - val_loss: 9.4811e-04
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.7899e-04 - val_loss: 9.0872e-04
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.8567e-04 - val_loss: 0.0023
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0010 - val_loss: 8.9636e-04
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.7103e-04 - val_loss: 0.0014
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.3319e-04 - val_loss: 8.8718e-04
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.4209e-04 - val_loss: 0.0013
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.0690e-04 - val_loss: 8.4894e-04
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.7962e-04 - val_loss: 8.0920e-04
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.3263e-04 - val_loss: 0.0011
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.6611e-04 - val_loss: 8.5296e-04
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.7643e-04 - val_loss: 8.9392e-04
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.6797e-04 - val_loss: 9.5718e-04
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.1739e-04 - val_loss: 0.0012
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.9548e-04 - val_loss: 6.0774e-04
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.6094e-04 - val_loss: 8.6079e-04
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.1328e-04 - val_loss: 5.7973e-04
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.7123e-04 - val_loss: 8.8111e-04
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.1786e-04 - val_loss: 5.6254e-04
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.9970e-04 - val_loss: 5.4457e-04
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.6606e-04 - val_loss: 5.6001e-04
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.6160e-04 - val_loss: 9.5202e-04
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.6929e-04 - val_loss: 5.9643e-04
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.5705e-04 - val_loss: 5.0295e-04
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.6014e-04 - val_loss: 5.4337e-04
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.1848e-04 - val_loss: 8.3891e-04
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.9299e-04 - val_loss: 0.0012
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss:
-04
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0017 - val_loss: 2.1637e-04
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0018 - val_loss: 6.0421e-04
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0017 - val_loss: 2.0722e-04
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0017 - val_loss: 2.2372e-04
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0015 - val_loss: 4.1077e-04
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0016 - val_loss: 1.8241e-04
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0014 - val_loss: 2.1923e-04
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0016 - val_loss: 2.6357e-04
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0015 - val_loss: 2.0971e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Fungsi untuk evaluasi
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    return rmse, mae

def denormalize_data(scaled_data, dataset_name):
    return scalers[dataset_name].inverse_transform(scaled_data)

# %%
# Evaluasi model dan membuat prediksi
evaluations = {}
predictions = {}

for file, model in model_results.items():
    X_test = split_datasets[file][1].reshape(-1, 60, 1)
    y_test = split_datasets[file][3]
    
    # Membuat prediksi
    y_pred_scaled = model.predict(X_test)
    
    # Denormalisasi
    y_pred_rescaled = denormalize_data(y_pred_scaled, file)
    y_test_rescaled = denormalize_data(y_test.reshape(-1, 1), file)
    
    # Menghitung metrik
    rmse, mae = evaluate_model(model, X_test, y_test)
    evaluations[file] = {'RMSE': rmse, 'MAE': mae}
    
    predictions[file] = {
        'y_pred': y_pred_rescaled,
        'y_test': y_test_rescaled
    }
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
# Fungsi untuk memplot prediksi
def plot_predictions(file, predictions, evaluations):
    y_pred = predictions[file]['y_pred']
    y_test = predictions[file]['y_test']
    
    plt.figure(figsize=(12, 6))
    plt.plot(y_test, label='Harga Aktual', linewidth=2)
    plt.plot(y_pred, label='Harga Prediksi', linewidth=2)
    plt.title(f'Prediksi Harga BPP untuk {file}\nRMSE: {evaluations[file]["RMSE"]:.2f}, MAE: {evaluations[file]["MAE"]:.2f}')
    plt.xlabel('Waktu')
    plt.ylabel('Harga (Rupiah)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Plot hasil untuk setiap dataset
for file in predictions.keys():
    plot_predictions(file, predictions, evaluations)

# Menampilkan hasil evaluasi akhir
print("\nHasil Evaluasi Akhir:")
for name, metrics in evaluations.items():
    print(f"\nMetrik untuk {name}:")
    print(f"RMSE: {metrics['RMSE']:.4f}")
    print(f"MAE: {metrics['MAE']:.4f}")
# Out:
# Hasil Evaluasi Akhir:
#
# Metrik untuk bawang_merah.csv:
# RMSE: 0.0196
# MAE: 0.0148
#
# Metrik untuk bawang_putih.csv:
# RMSE: 0.0119
# MAE: 0.0084
#
# Metrik untuk beras_medium.csv:
# RMSE: 0.0146
# MAE: 0.0105
#
# Metrik untuk beras_premium.csv:
# RMSE: 0.0143
# MAE: 0.0105
#
# Metrik untuk cabai_merah_keriting.csv:
# RMSE: 0.0189
# MAE: 0.0119
#
# Metrik untuk cabai_rawit_merah.csv:
# RMSE: 0.0191
# MAE: 0.0149
#
# Metrik untuk daging_ayam_ras.csv:
# RMSE: 0.0288
# MAE: 0.0184
#
# Metrik untuk daging_sapi.csv:
# RMSE: 0.0654
# MAE: 0.0336
#
# Metrik untuk gula_pasir.csv:
# RMSE: 0.0105
# MAE: 0.0076
#
# Metrik untuk kedelai.csv:
# RMSE: 0.0313
# MAE: 0.0190
#
# Metrik untuk telur_ayam_ras.csv:
# RMSE: 0.0145
# MAE: 0.0101

# %%
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_20 (LSTM)                  │ (None, 60, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_21 (LSTM)                  │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 91,955 (359.20 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 61,304 (239.47 KB)
